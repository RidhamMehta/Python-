# %%
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np

# Initial Data
X = [1, 2, 3, 4, 5]
Y = [2, 4, 5, 4, 5]

# %%
data = stats.linregress(X, Y)
print(">> Slope is:", data[0])
print(">> Interceptor is:", data[1])
print(">> Equation of Line: y = {} + {} * x".format(data[1], data[0]))
# Out:
# >> Slope is: 0.6000000000000001
# >> Interceptor is: 2.1999999999999997
# >> Equation of Line: y = 2.1999999999999997 + 0.6000000000000001 * x

# %%
maxX = np.max(X) + 10
minY = np.min(Y) - 10

print("maxX:", maxX)
print("minY:", minY)
# Out:
# maxX: 15
# minY: -8

# %%
x = np.linspace(minY, maxX, 100)
y = data[1] + data[0] * x

print(x)
print("----------")
print(y)
# Out:
# [-8.         -7.76767677 -7.53535354 -7.3030303  -7.07070707 -6.83838384
#  -6.60606061 -6.37373737 -6.14141414 -5.90909091 -5.67676768 -5.44444444
#  -5.21212121 -4.97979798 -4.74747475 -4.51515152 -4.28282828 -4.05050505
#  -3.81818182 -3.58585859 -3.35353535 -3.12121212 -2.88888889 -2.65656566
#  -2.42424242 -2.19191919 -1.95959596 -1.72727273 -1.49494949 -1.26262626
#  -1.03030303 -0.7979798  -0.56565657 -0.33333333 -0.1010101   0.13131313
#   0.36363636  0.5959596   0.82828283  1.06060606  1.29292929  1.52525253
#   1.75757576  1.98989899  2.22222222  2.45454545  2.68686869  2.91919192
#   3.15151515  3.38383838  3.61616162  3.84848485  4.08080808  4.31313131
#   4.54545455  4.77777778  5.01010101  5.24242424  5.47474747  5.70707071
#   5.93939394  6.17171717  6.4040404   6.63636364  6.86868687  7.1010101
#   7.33333333  7.56565657  7.7979798   8.03030303  8.26262626  8.49494949
#   8.72727273  8.95959596  9.19191919  9.42424242  9.65656566  9.88888889
#  10.12121212 10.35353535 10.58585859 10.81818182 11.05050505 11.28282828
#  11.51515152 11.74747475 11.97979798 12.21212121 12.44444444 12.67676768
#  12.90909091 13.14141414 13.37373737 13.60606061 13.83838384 14.07070707
#  14.3030303  14.53535354 14.76767677 15.        ]
# ----------
# [-2.6        -2.46060606 -2.32121212 -2.18181818 -2.04242424 -1.9030303
#  -1.76363636 -1.62424242 -1.48484848 -1.34545455 -1.20606061 -1.06666667
#  -0.92727273 -0.78787879 -0.64848485 -0.50909091 -0.36969697 -0.23030303
#  -0.09090909  0.04848485  0.18787879  0.32727273  0.46666667  0.60606061
#   0.74545455  0.88484848  1.02424242  1.16363636  1.3030303   1.44242424
#   1.58181818  1.72121212  1.86060606  2.          2.13939394  2.27878788
#   2.41818182  2.55757576  2.6969697   2.83636364  2.97575758  3.11515152
#   3.25454545  3.39393939  3.53333333  3.67272727  3.81212121  3.95151515
#   4.09090909  4.23030303  4.36969697  4.50909091  4.64848485  4.78787879
#   4.92727273  5.06666667  5.20606061  5.34545455  5.48484848  5.62424242
#   5.76363636  5.9030303   6.04242424  6.18181818  6.32121212  6.46060606
#   6.6         6.73939394  6.87878788  7.01818182  7.15757576  7.2969697
#   7.43636364  7.57575758  7.71515152  7.85454545  7.99393939  8.13333333
#   8.27272727  8.41212121  8.55151515  8.69090909  8.83030303  8.96969697
#   9.10909091  9.24848485  9.38787879  9.52727273  9.66666667  9.80606061
#   9.94545455 10.08484848 10.22424242 10.36363636 10.5030303  10.64242424
#  10.78181818 10.92121212 11.06060606 11.2       ]

# %%
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.plot(x, y, color="red", label="Regression Line")
plt.scatter(X, Y, color="blue", label="Data Points")
plt.legend()
plt.show()
